# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
### Here we want to import FAOSTAT csv file and extract required informaion using pandas dataframe 
FAOSTAT12312018 = pd.read_csv("/Users/kyawmoeaung/Downloads/FAOSTAT_data_12-31-2018.csv")

# %%
FAOSTAT12312018.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value', 'Flag',
#        'Flag Description'],
#       dtype='object')

# %%
print(pd.unique(FAOSTAT12312018["Item"]))
# Out:
# ['Areca nuts' 'Barley' 'Bastfibres, other' 'Beans, dry'
#  'Cashew nuts, with shell' 'Cassava' 'Castor oil seed' 'Cereals, nes'
#  'Chick peas' 'Chillies and peppers, dry' 'Coconuts' 'Coffee, green'
#  'Cow peas, dry' 'Fibre crops nes' 'Fruit, fresh nes'
#  'Fruit, tropical fresh nes' 'Garlic' 'Groundnuts, with shell' 'Jute'
#  'Lentils' 'Maize' 'Mangoes, mangosteens, guavas' 'Millet' 'Mustard seed'
#  'Onions, dry' 'Peas, dry' 'Pigeon peas' 'Plantains and others' 'Potatoes'
#  'Rice, paddy' 'Rubber, natural' 'Seed cotton' 'Sesame seed' 'Sorghum'
#  'Soybeans' 'Spices, nes' 'Sugar cane' 'Sugar crops, nes' 'Sunflower seed'
#  'Sweet potatoes' 'Tea' 'Tobacco, unmanufactured' 'Vegetables, fresh nes'
#  'Wheat']

# %%
print(pd.unique(FAOSTAT12312018["Year"]))
# Out:
# [1961 1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990
#  1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005
#  2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017]

# %%
# Now we are going to reorganize columns 
cols = FAOSTAT12312018[["Item", "Year", "Unit", "Value"]]

# %%
maize = FAOSTAT12312018["Item"] == "Maize"
cols = FAOSTAT12312018[["Item", "Year", "Unit", "Value"]]
maizeData = FAOSTAT12312018[maize]
maizeData[["Item", "Year", "Unit", "Value"]]
# Out:
#        Item  Year Unit     Value
# 1115  Maize  1961   ha   67860.0
# 1116  Maize  1962   ha  126088.0
# 1117  Maize  1963   ha   99446.0
# 1118  Maize  1964   ha   82338.0
# 1119  Maize  1965   ha   79405.0
# 1120  Maize  1966   ha   90815.0
# 1121  Maize  1967   ha   94752.0
# 1122  Maize  1968   ha   82140.0
# 1123  Maize  1969   ha   68932.0
# 1124  Maize  1970   ha   67164.0
# 1125  Maize  1971   ha   77216.0
# 1126  Maize  1972   ha   79513.0
# 1127  Maize  1973   ha   80493.0
# 1128  Maize  1974   ha   79252.0
# 1129  Maize  1975   ha   76972.0
# 1130  Maize  1976   ha   75685.0
# 1131  Maize  1977   ha   79117.0
# 1132  Maize  1978   ha   83252.0
# 1133  Maize  1979   ha  100096.0
# 1134  Maize  1980   ha  144483.0
# 1135  Maize  1981   ha  140568.0
# 1136  Maize  1982   ha  135908.0
# 1137  Maize  1983   ha  180800.0
# 1138  Maize  1984   ha  186172.0
# 1139  Maize  1985   ha  170869.0
# 1140  Maize  1986   ha  159127.0
# 1141  Maize  1987   ha  134781.0
# ...

# %%
#x = maizeData["Year"]
#y = maizeData["Value"]
#plt.plot(x,y)
plt.plot(maizeData["Year"], maizeData["Value"])
plt.title("Maize production in Myanmar - 1960 to 2017")
plt.table
plt.show()

# %%
rice = FAOSTAT12312018["Item"] == "Rice, paddy"
riceData = FAOSTAT12312018[rice]
riceData[["Item", "Year", "Unit", "Value"]]
plt.plot(riceData["Year"], riceData["Value"])
plt.show()

# %%
sugarCane = FAOSTAT12312018["Item"] == "Sugar cane"
sugarCaneData = FAOSTAT12312018[sugarCane]
sugarCaneData[["Item", "Year", "Unit", "Value"]]
plt.plot(sugarCaneData["Year"], sugarCaneData["Value"])
plt.show()

# %%
cerealsNes = FAOSTAT12312018["Item"] == "Cereals, nes"
cerealsNesData = FAOSTAT12312018[cerealsNes]
cerealsNesData[["Item", "Year", "Unit", "Value"]]
plt.plot(cerealsNesData["Year"], cerealsNesData["Value"])
plt.show()

# %%
rubber = FAOSTAT12312018["Item"] == "Rubber, natural"
rubberData = FAOSTAT12312018[rubber]
rubberData[["Item", "Year", "Unit", "Value"]]
plt.plot(rubberData["Year"], rubberData["Value"])
plt.show()

# %%
sesameSeed = FAOSTAT12312018["Item"] == "Sesame seed"
sesameData = FAOSTAT12312018[sesameSeed]
sesameData[["Item", "Year", "Unit", "Value"]]
plt.plot(sesameData["Year"], sesameData["Value"])
plt.title("Sesame production in Myanmar - 1960 to 2017")
plt.show()

# %%
groundNut = FAOSTAT12312018["Item"] == "Groundnuts, with shell"
groundNutData = FAOSTAT12312018[groundNut]
groundNutData[["Item", "Year", "Unit", "Value"]]
plt.plot(groundNutData["Year"], groundNutData["Value"])
plt.title("Groundnuts production in Myanmar - 1960 to 2017")
plt.show()

# %%
beansDry = FAOSTAT12312018["Item"] == "Beans, dry"
beansDryData = FAOSTAT12312018[beansDry]
beansDryData[["Item", "Year", "Unit", "Value"]]
plt.plot(beansDryData["Year"], beansDryData["Value"])
plt.title("Beans production in Myanmar - 1960 to 2017")
plt.show()

# %%
tea = FAOSTAT12312018["Item"] == "Tea"
teaData = FAOSTAT12312018[tea]
teaData[["Item", "Year", "Unit", "Value"]]
plt.plot(teaData["Year"], teaData["Value"])
plt.title("Tea production in Myanmar - 1960 to 2017")
plt.show()

# %%
plt.title?
